# %% [markdown]
# <a href="https://colab.research.google.com/github/vlkumar-859/AI_ML/blob/master/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df['Altitude'].mean()
min(l['Altitude'])
l=df.head()
l
# Out:
#    Latitude ° Latitude  ...  Wireless Power Zero-Space Computing
# 0           0        S  ...           False                 True
# 1           0        S  ...           False                False
# 2           0        S  ...           False                False
# 3           0        S  ...           False                False
# 4           0        S  ...           False                 True
#
# [5 rows x 79 columns]

# %%
min(l['Altitude'])
# Out:
# -1160

# %%
l['Altitude'].mean()
# Out:
# -1067.6

# %%
df=pd.read_csv("/content/edited MapData-Evans-GP-Flatten.csv")
df.head(20)
# Out:
#     Unnamed: 0 Latitude  Longitude °  ... Dust Storms Meteors  Cold Waves
# 0            0        S            0  ...           1       4           1
# 1            0        S            1  ...           1       4           1
# 2            0        S            1  ...           2       4           1
# 3            0        S            2  ...           1       4           1
# 4            0        S            2  ...           3       4           1
# 5            0        S            3  ...           1       4           1
# 6            0        S            3  ...           3       4           1
# 7            0        S            4  ...           1       4           1
# 8            0        S            4  ...           3       4           1
# 9            0        S            5  ...           1       4           1
# 10           0        S            5  ...           3       4           1
# 11           0        S            6  ...           2       4           1
# ...
